# %% [markdown]
# # RU-WRF 4.1: Create map of Wind Speeds
#
# _Written by Lori Garzio, June 10, 2020_
#
# [Rutgers Center for Ocean Observing Leadership](https://rucool.marine.rutgers.edu/) (RUCOOL)
#
# This notebook demonstrates how to access data from the Rutgers University Weather Research and Forecasting Model (RU-WRF 4.1) from the [RUWRF THREDDs server](http://tds.marine.rutgers.edu/thredds/cool/ruwrf/catalog.html), subset the data for a specific time range and defined latitude/longitude grid, grab the u and v components of wind speed from the file at a defined height, plot a surface pseudocolor map for each hour output of the model, add contours, quivers and map feature layers, and save the plots to your local machine.
#
# _**WARNING**: the model output is very large and these plots take several minutes to generate. Please restrict your time range to <24 hours to avoid crashing the THREDDs server._

# %%
# import the required packages for data access and plotting
import datetime as dt
import xarray as xr
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %% [markdown]
# ## Data Access
#
# The RU-WRF 4.1 THREDDs server can be accessed [here](http://tds.marine.rutgers.edu/thredds/cool/ruwrf/catalog.html). For this example, we will be using the [Best](http://tds.marine.rutgers.edu/thredds/catalog/cool/ruwrf/wrf_4_1_3km_processed/catalog.html?dataset=cool/ruwrf/wrf_4_1_3km_processed/WRF_4.1_3km_Processed_Dataset_Best) dataset from the WRF 4.1 3km Processed Dataset, however the 9km Processed Dataset can be accessed in the same way, has the same file format and contains the same variables.
#
# Once you've located the Best dataset and reviewed the documentation, you can access the data using Python via the Data URL found in the OPENDAP link. You will also need to specify:
#
# * the path to the local directory to which you want to save the plots
# * the minimum and maximum latitude and longitudes you want to plot
# * start and end times you want to subset to plot (**reminder**: keep to <24 hours)
# * the height at which you want to plot wind speeds
#
# _Some important information from the metadata page in the THREDDs server about time and geospatial coverage for this dataset:_
#
# **Geospatial Coverage:**
# * Longitude: -80.45 to -68.55 degrees_east
# * Latitude: 34.32 to 43.15 degrees_north
# * Altitude: 30.0 to 250.0 Resolution=10.0 m (positive is up)
#
# **Start Time:** 2019-01-01T00:00:00Z

# %%
# data url
wrf_file = 'http://tds.marine.rutgers.edu/thredds/dodsC/cool/ruwrf/wrf_4_1_3km_processed/WRF_4.1_3km_Processed_Dataset_Best'

# save file directory - change this to a local directory
save_dir = '/Users/lgarzio/Documents/rucool/tutorials'

# define the limits for the 3km model to subset and plot
model_lims = dict(minlon=-80, maxlon=-69, minlat=35, maxlat=43)

# start and end times for plotting - here we'll plot the first 5 hours of the model run on June 3, 2020.
start_time = dt.datetime(2020, 6, 3, 0, 0, 0)
end_time = dt.datetime(2020, 6, 3, 4, 0, 0)

# define height in meters for plotting wind speeds
ht = 10

# %% [markdown]
# Next, we'll use [xarray](https://pypi.org/project/xarray/) to open and subset the RU-WRF data file based on the start and end times you entered above.

# %%
# open the dataset
ds = xr.open_dataset(wrf_file, mask_and_scale=False)

# subset based on time
ds = ds.sel(time=slice(start_time, end_time))

# print the dataset to see the dimensions, coordinates, variables, etc
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (height: 23, south_north: 324, time: 5, west_east: 324)
# Coordinates:
#     XLONG        (south_north, west_east) float32 ...
#     XLAT         (south_north, west_east) float32 ...
#   * height       (height) int32 30 40 50 60 70 80 90 ... 200 210 220 230 240 250
#   * time         (time) datetime64[ns] 2020-06-03 ... 2020-06-03T04:00:00
#     time_run     (time) datetime64[ns] ...
# Dimensions without coordinates: south_north, west_east
# Data variables:
#     T2           (time, south_north, west_east) float32 ...
#     SWDOWN       (time, south_north, west_east) float32 ...
#     LWUPB        (time, south_north, west_east) float32 ...
#     GLW          (time, south_north, west_east) float32 ...
#     PSFC         (time, south_north, west_east) float32 ...
#     RAINC        (time, south_north, west_east) float32 ...
#     RAINNC       (time, south_north, west_east) float32 ...
#     RAINSH       (time, south_north, west_east) float32 ...
#     U10          (time, south_north, west_east) float32 ...
#     V10          (time, south_north, west_east) float32 ...
#     RH2          (time, south_north, west_east) float32 ...
#     SLP          (time, south_north, west_east) float32 ...
#     U            (time, height, south_north, west_east) float32 ...
#     V            (time, height, south_north, west_east) float32 ...
#     XTIME        timedelta64[ns] ...
#     time_offset  (time) datetime64[ns] ...
# Attributes:
#     title:                           Rutgers Weather Research and Forecasting...
#     summary:                         Processed netCDF containing subset of RU...
#     keywords:                        Weather Advisories > Marine Weather/Fore...
#     Conventions:                     CF-1.4
#     naming_authority:                edu.rutgers.marine.rucool
#     processing_level:                Level 2
#     comment:                         WRF Model operated by RUCOOL
#     acknowledgement:                 This data is provided by the Rutgers Cen...
#     standard_name_vocabulary:        CF Standard Name Table v41
#     creator_name:                    Joseph Brodie
#     creator_email:                   jbrodie@marine.rutgers.edu
#     creator_url:                     rucool.marine.rutgers.edu
#     institution:                     Center for Ocean Observing and Leadershi...
#     project:                         New Jersey Board of Public Utilities - O...
#     geospatial_lat_min:              34.3211
#     geospatial_lat_max:              43.1536
#     geospatial_lon_min:              -80.4476
#     geospatial_lon_max:              -68.5524
#     creator_type:                    person
#     creator_institution:             Rutgers University
#     contributor_name:                Joseph Brodie
#     contributor_role:                Director of Atmospheric Research
#     geospatial_lat_units:            degrees_north
#     geospatial_lon_units:            degrees_east
#     keywords_vocabulary:             GCMD Science Keywords
#     platform:                        WRF Model Run
#     cdm_data_type:                   GRID
#     references:                      https://rucool.marine.rutgers.edu/data/m...
#     TITLE:                            OUTPUT FROM WRF V4.1.2 MODEL
#     WEST-EAST_GRID_DIMENSION:        325
#     SOUTH-NORTH_GRID_DIMENSION:      325
#     BOTTOM-TOP_GRID_DIMENSION:       48
#     DX:                              3000.0
#     DY:                              3000.0
#     AERCU_OPT:                       0
#     AERCU_FCT:                       1.0
#     IDEAL_CASE:                      0
#     DIFF_6TH_SLOPEOPT:               0
#     AUTO_LEVELS_OPT:                 2
#     DIFF_6TH_THRESH:                 0.1
#     DZBOT:                           50.0
#     DZSTRETCH_S:                     1.3
#     DZSTRETCH_U:                     1.1
#     SKEBS_ON:                        0
#     SPEC_BDY_FINAL_MU:               1
#     USE_Q_DIABATIC:                  0
#     GRIDTYPE:                        C
#     DIFF_OPT:                        1
#     KM_OPT:                          4
#     DAMP_OPT:                        0
#     DAMPCOEF:                        0.2
#     KHDIF:                           0.0
#     KVDIF:                           0.0
#     MP_PHYSICS:                      8
#     RA_LW_PHYSICS:                   4
#     RA_SW_PHYSICS:                   5
#     SF_SFCLAY_PHYSICS:               5
#     SF_SURFACE_PHYSICS:              2
#     BL_PBL_PHYSICS:                  5
#     CU_PHYSICS:                      0
#     SF_LAKE_PHYSICS:                 0
#     SURFACE_INPUT_SOURCE:            3
#     SST_UPDATE:                      0
#     GRID_FDDA:                       0
#     GFDDA_INTERVAL_M:                0
#     GFDDA_END_H:                     0
#     GRID_SFDDA:                      0
#     SGFDDA_INTERVAL_M:               0
#     SGFDDA_END_H:                    0
#     HYPSOMETRIC_OPT:                 2
#     USE_THETA_M:                     1
#     GWD_OPT:                         0
#     SF_URBAN_PHYSICS:                0
#     SF_SURFACE_MOSAIC:               0
#     SF_OCEAN_PHYSICS:                0
#     SHCU_PHYSICS:                    0
#     MFSHCONV:                        0
#     FEEDBACK:                        1
#     SMOOTH_OPTION:                   0
#     SWRAD_SCAT:                      1.0
#     W_DAMPING:                       1
#     ADAPT_DT_START:                  12.0
#     ADAPT_DT_MAX:                    24.0
#     ADAPT_DT_MIN:                    9.0
#     RADT:                            9.0
#     BLDT:                            0.0
#     CUDT:                            0.0
#     AER_OPT:                         0
#     SWINT_OPT:                       0
#     AER_TYPE:                        1
#     AER_AOD550_OPT:                  1
#     AER_ANGEXP_OPT:                  1
#     AER_SSA_OPT:                     1
#     AER_ASY_OPT:                     1
#     AER_AOD550_VAL:                  0.12
#     AER_ANGEXP_VAL:                  1.3
#     AER_SSA_VAL:                     0.85
#     AER_ASY_VAL:                     0.9
#     MOIST_ADV_OPT:                   1
#     SCALAR_ADV_OPT:                  1
#     TKE_ADV_OPT:                     1
#     DIFF_6TH_OPT:                    2
#     DIFF_6TH_FACTOR:                 0.12
#     OBS_NUDGE_OPT:                   0
#     BUCKET_MM:                       -1.0
#     BUCKET_J:                        -1.0
#     PREC_ACC_DT:                     60.0
#     ISFTCFLX:                        0
#     ISHALLOW:                        0
#     ISFFLX:                          1
#     ICLOUD:                          0
#     ICLOUD_CU:                       0
#     TRACER_PBLMIX:                   1
#     SCALAR_PBLMIX:                   0
#     YSU_TOPDOWN_PBLMIX:              0
#     GRAV_SETTLING:                   1
#     DFI_OPT:                         0
#     SIMULATION_INITIALIZATION_TYPE:  REAL-DATA CASE
#     WEST-EAST_PATCH_START_UNSTAG:    1
#     WEST-EAST_PATCH_END_UNSTAG:      324
#     WEST-EAST_PATCH_START_STAG:      1
#     WEST-EAST_PATCH_END_STAG:        325
#     SOUTH-NORTH_PATCH_START_UNSTAG:  1
#     SOUTH-NORTH_PATCH_END_UNSTAG:    324
#     SOUTH-NORTH_PATCH_START_STAG:    1
#     SOUTH-NORTH_PATCH_END_STAG:      325
#     BOTTOM-TOP_PATCH_START_UNSTAG:   1
#     BOTTOM-TOP_PATCH_END_UNSTAG:     47
#     BOTTOM-TOP_PATCH_START_STAG:     1
#     BOTTOM-TOP_PATCH_END_STAG:       48
#     GRID_ID:                         2
#     PARENT_ID:                       1
#     I_PARENT_START:                  42
#     J_PARENT_START:                  59
#     PARENT_GRID_RATIO:               3
#     CEN_LAT:                         38.800003
#     CEN_LON:                         -74.5
#     TRUELAT1:                        38.8
#     TRUELAT2:                        38.8
#     MOAD_CEN_LAT:                    38.75293
#     STAND_LON:                       -74.5
#     POLE_LAT:                        90.0
#     POLE_LON:                        0.0
#     MAP_PROJ:                        1
#     MAP_PROJ_CHAR:                   Lambert Conformal
#     MMINLU:                          MODIFIED_IGBP_MODIS_NOAH
#     NUM_LAND_CAT:                    21
#     ISWATER:                         17
#     ISLAKE:                          21
#     ISICE:                           15
#     ISURBAN:                         13
#     ISOILWATER:                      14
#     HYBRID_OPT:                      2
#     ETAC:                            0.2
#     _CoordSysBuilder:                ucar.nc2.dataset.conv.CF1Convention
#     featureType:                     GRID
#     location:                        Proto fmrc:wrf_4_1_3km_processed
#     history:                         FMRC Best Dataset
#     DODS_EXTRA.Unlimited_Dimension:  Time
#     EXTRA_DIMENSION.string19:        19
#     EXTRA_DIMENSION.Time:            1
#     EXTRA_DIMENSION.Times:           1

# %%
# grab the time, latitude, and longitude variables
time = ds['time']
lon = ds['XLONG']
lat = ds['XLAT']

# print the time variable - this data subset only contains data from within the requested timeframe
time
# Out:
# <xarray.DataArray 'time' (time: 5)>
# array(['2020-06-03T00:00:00.000000000', '2020-06-03T01:00:00.000000000',
#        '2020-06-03T02:00:00.000000000', '2020-06-03T03:00:00.000000000',
#        '2020-06-03T04:00:00.000000000'], dtype='datetime64[ns]')
# Coordinates:
#   * time      (time) datetime64[ns] 2020-06-03 ... 2020-06-03T04:00:00
#     time_run  (time) datetime64[ns] ...
# Attributes:
#     long_name:            Forecast time for ForecastModelRunCollection
#     standard_name:        time
#     missing_value:        nan
#     _CoordinateAxisType:  Time

# %% [markdown]
# Next, we'll look at the latitude variable. Since latitude and longitude are 2D arrays we will need to geospatially subset the data by creating indices to use in the subsetting. We'll create those indices by finding where the latitude and longitude values are within the limits we defined above.

# %%
# 2D array
print('Latitude shape: {}'.format(np.shape(lat)))
lat.values
# Out:
# Latitude shape: (324, 324)
# array([[34.321144, 34.32268 , 34.324215, ..., 34.324215, 34.32268 ,
#         34.321144],
#        [34.348   , 34.349537, 34.35108 , ..., 34.35108 , 34.349537,
#         34.348   ],
#        [34.37486 , 34.376396, 34.37794 , ..., 34.37794 , 34.376396,
#         34.37486 ],
#        ...,
#        [42.95856 , 42.960304, 42.962032, ..., 42.962032, 42.960304,
#         42.95856 ],
#        [42.985413, 42.987152, 42.988888, ..., 42.988888, 42.987152,
#         42.985413],
#        [43.012268, 43.014008, 43.015747, ..., 43.015747, 43.014008,
#         43.012268]], dtype=float32)

# %%
# create boolean indices where lat/lon are within defined boundaries
lon_ind = np.logical_and(lon > model_lims['minlon'], lon < model_lims['maxlon'])
lat_ind = np.logical_and(lat > model_lims['minlat'], lat < model_lims['maxlat'])

# print the lon_ind to see what the code above created
lon_ind
# Out:
# <xarray.DataArray 'XLONG' (south_north: 324, west_east: 324)>
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])
# Coordinates:
#     XLONG    (south_north, west_east) float32 -79.76373 -79.7312 ... -68.55237
#     XLAT     (south_north, west_east) float32 34.321144 34.32268 ... 43.012268
# Dimensions without coordinates: south_north, west_east

# %%
# find i and j indices of lon/lat in boundaries
ind = np.where(np.logical_and(lon_ind, lat_ind))

# %% [markdown]
# We will use this index when we grab the data to plot at every time step.
#
# ## Set up plot for one timestamp
#
# Here is a function to plot the data, add contours at defined levels, add quivers to indicate wind direction, add map features to the plot, and save the plot to a directory on your local machine (if the file path is provided).

# %%
def plot_wndsp(plt_ttl, clabel, lon_data, lat_data, u, v, wndsp, save_figname=None):
    """
    Create pseudocolor surface map of wind speed with quivers indicating wind direction.
    plt_ttl: title for the plot
    clabel: label for the color bar
    lon_data: longitude data
    lat_data: latitude data
    data: variable data
    save_figname: optional, full file path to save directory and save filename
    """
    # set up the map
    lccproj = ccrs.LambertConformal(central_longitude=-74.5, central_latitude=38.8)
    fig, ax = plt.subplots(figsize=(8, 9), subplot_kw=dict(projection=lccproj))

    plt.subplots_adjust(right=0.88)  # adjust the right margin of the plot
    plt.title(plt_ttl, fontsize=17)  # add the title

    # format the spacing of the colorbar
    divider = make_axes_locatable(ax)
    cax = divider.new_horizontal(size='5%', pad=0.1, axes_class=plt.Axes)
    fig.add_axes(cax)

    # plot the data
    h = ax.pcolor(lon_data, lat_data, wndsp, vmin=0, vmax=75, cmap='BuPu', transform=ccrs.PlateCarree())

    # add the color bar
    cb = plt.colorbar(h, cax=cax)
    cb.set_label(label=clabel, fontsize=14)  # add the label on the colorbar
    cb.ax.tick_params(labelsize=12)  # format the size of the tick labels
    
    # subset the quivers and add as a layer
    sub = 10
    ax.quiver(lons[::sub, ::sub], lats[::sub, ::sub], u[::sub, ::sub], v[::sub, ::sub], scale=1000,
              width=.002, headlength=4, transform=ccrs.PlateCarree())

    # add contours
    contour_list = [25, 34, 48]  # define contour levels
    cs = ax.contour(lon_data, lat_data, wndsp, contour_list, colors='black', linewidths=.5, transform=ccrs.PlateCarree())
    ax.clabel(cs, inline=True, fontsize=10.5, fmt='%d')

    # add the latitude and longitude gridlines
    gl = ax.gridlines(draw_labels=True, linewidth=1, color='gray', alpha=0.5, linestyle='dotted', x_inline=False)
    gl.top_labels = False
    gl.right_labels = False
    gl.xlabel_style = {'size': 13}
    gl.ylabel_style = {'size': 13}

    # add map features
    land = cfeature.NaturalEarthFeature('physical', 'land', '10m')
    ax.add_feature(land, zorder=5, edgecolor='black', facecolor='none')

    state_lines = cfeature.NaturalEarthFeature(
        category='cultural',
        name='admin_1_states_provinces_lines',
        scale='10m',
        facecolor='none')

    ax.add_feature(cfeature.BORDERS, zorder=6)
    ax.add_feature(state_lines, zorder=7, edgecolor='black')

    # save the figure only if a figure path is provided
    if save_figname is not None:
        plt.savefig(save_figname, dpi=200)

# %% [markdown]
# Now, we will get the data for the u and v wind components just at the first timestamp in the time array, subset the grid using the latitude/longitude index created earlier, convert the units from m/s to knots, calculate wind speeds and pass all of the information to the plotting function to create the image.
#
# The u and v wind components at 10m height are separate variables (U10 and V10) from the u and v wind components at heights 30-250m (U and V), so you will have to grab the data from the file in slightly different ways depending on what height you want to plot. In this example we're plotting data at 10m (we specified ht = 10 at the beginning of the tutorial), so we will be grabbing U10 and V10.

# %%
# get the data u and v at the user-defined height at the first timestamp in the time array
t = time[0]  # grab the first timestamp

if ht == 10:
    u = ds.U10.sel(time=t.values)
    v = ds.V10.sel(time=t.values)
else:
    u = ds.U.sel(time=t.values, height=ht)
    v = ds.V.sel(time=t.values, height=ht)
print(u)
# Out:
# <xarray.DataArray 'U10' (south_north: 324, west_east: 324)>
# [104976 values with dtype=float32]
# Coordinates:
#     XLONG     (south_north, west_east) float32 -79.76373 -79.7312 ... -68.55237
#     XLAT      (south_north, west_east) float32 34.321144 34.32268 ... 43.012268
#     time      datetime64[ns] 2020-06-03
#     time_run  datetime64[ns] ...
# Dimensions without coordinates: south_north, west_east
# Attributes:
#     units:          m s-1
#     long_name:      Eastward Wind Component - 10m
#     _FillValue:     nan
#     description:    10m earth rotated u
#     standard_name:  eastward_wind
#     short_name:     u
#     valid_min:      -300.0
#     valid_max:      300.0
#     _ChunkSizes:    [  1 324 324]

# %%
# subset data from min i,j lat/lon corner to max i,j lat/lon corner
# there will be some points outside of defined boundaries because grid is not rectangular
u = np.squeeze(u)[range(np.min(ind[0]), np.max(ind[0]) + 1), range(np.min(ind[1]), np.max(ind[1]) + 1)]
v = np.squeeze(v)[range(np.min(ind[0]), np.max(ind[0]) + 1), range(np.min(ind[1]), np.max(ind[1]) + 1)]
lons = u['XLONG'].values
lats = u['XLAT'].values

# convert wind components from m/s to knots
u = u * 1.94384
v = v * 1.94384
print(u)

# calculate wind speed
ws = np.sqrt(np.square(u) + np.square(v))
# Out:
# <xarray.DataArray 'U10' (south_north: 301, west_east: 324)>
# array([[ 2.506002,  2.774693,  2.837878, ..., 12.884603, 12.835271, 12.897455],
#        [ 2.441979,  2.740182,  2.773299, ..., 13.013481, 12.975133, 13.041121],
#        [ 2.560692,  2.941589,  3.082325, ..., 13.07305 , 13.151631, 13.250648],
#        ...,
#        [ 6.142581,  6.443268,  6.862429, ...,  4.225197,  4.24956 ,  4.370718],
#        [ 5.922872,  6.057368,  6.523831, ...,  4.323477,  4.412741,  4.559543],
#        [ 6.053816,  6.088336,  6.261516, ...,  4.448935,  4.487664,  4.663465]],
#       dtype=float32)
# Coordinates:
#     XLONG     (south_north, west_east) float32 -79.803375 -79.7706 ... -68.55716
#     XLAT      (south_north, west_east) float32 34.88536 34.886917 ... 42.95856
#     time      datetime64[ns] 2020-06-03
#     time_run  datetime64[ns] ...
# Dimensions without coordinates: south_north, west_east

# %% [markdown]
# Define information for the plot, like the label names and save file path.

# %%
# define labels for plot
timestr = dt.datetime.strftime(pd.to_datetime(t.values), '%Y-%m-%d %H:%M')  # convert timestamp to string
print(timestr)
time_edt = pd.to_datetime(t.values) - dt.timedelta(hours=4)
timestr_edt = dt.datetime.strftime(time_edt, '%Y-%m-%d %H:%M')
title = 'WRF 4.1 {}m Wind Speed\n{} GMT | {} EDT'.format(str(ht), timestr, timestr_edt)
color_label = 'Wind Speed (knots)'
# Out:
# 2020-06-03 00:00

# %% [markdown]
# ## Generate Plots
#
# Finally, let's pass the information to the function to create a plot. It may take several minutes to create this plot. This time, we won't pass the save file path (the last argument) to the function,  so the plot will be displayed below but not saved to your local machine. After we confirm the plotting function works, we can write a loop to make more than one plot and save those plots to your local machine.

# %%
# pass the necessary information to the function to create the plot (without the save file path)
plot_wndsp(title, color_label, lons, lats, u.values, v.values, ws.values)

# %% [markdown]
# Here is a surface image of wind speeds from the model. The data min and max for plotting are set at 0 to 75 knots so that multiple plots have the same color range. Those limits can be removed so the colors will dynamically change based on the data range. We're using the 'BuPu' colormap for this plot - you can start [here](https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html) for a matplotlib colormap tutorial, and there are many other resources for additional colormaps. The other components of this map can also be customized, such as the contours, gridlines, label sizes, subsetting the quivers to add more or less to the map, etc.
#
# Now, let's generate plots for the entire subset time range and save those images. This will take several minutes.

# %%
for t in time:
    # get the appropriate variables at the user-defined height at each timestamp
    if ht == 10:
        u = ds.U10.sel(time=t.values)
        v = ds.U10.sel(time=t.values)
    else:
        u = ds.V.sel(time=t.values, height=ht)
        v = ds.V.sel(time=t.values, height=ht)
    
    # subset data from min i,j lat/lon corner to max i,j lat/lon corner
    # there will be some points outside of defined boundaries because grid is not rectangular
    u = np.squeeze(u)[range(np.min(ind[0]), np.max(ind[0]) + 1), range(np.min(ind[1]), np.max(ind[1]) + 1)]
    v = np.squeeze(v)[range(np.min(ind[0]), np.max(ind[0]) + 1), range(np.min(ind[1]), np.max(ind[1]) + 1)]
    lons = u['XLONG'].values
    lats = u['XLAT'].values

    # convert wind components from m/s to knots
    u = u * 1.94384
    v = v * 1.94384

    # calculate wind speed from u and v
    ws = np.sqrt(np.square(u) + np.square(v))
    
    # define labels for plot
    timestr = dt.datetime.strftime(pd.to_datetime(t.values), '%Y-%m-%d %H:%M')  # convert timestamp to string
    print('Currently plotting: {}'.format(timestr))

    # convert time from GMT to EDT
    time_edt = pd.to_datetime(t.values) - dt.timedelta(hours=4)
    timestr_edt = dt.datetime.strftime(time_edt, '%Y-%m-%d %H:%M')  # convert timestamp to string

    # define plot title and color label title
    title = 'WRF 4.1 {}m Wind Speed\n{} GMT | {} EDT'.format(str(ht), timestr, timestr_edt)
    color_label = 'Wind Speed (knots)'
    
    # create a full save file path for the image
    model = wrf_file.split('/')[-1].split('_')[2]  # get the model version from the filename
    day = dt.datetime.strftime(pd.to_datetime(t.values), '%Y%m%d')
    hr = dt.datetime.strftime(pd.to_datetime(t.values), '%H')
    figname = 'windspeed{}_WRF_{}_{}_H{}.png'.format(str(ht), model, day, hr)
    sfig = os.path.join(save_dir, figname)
    print('save filepath: {}'.format(sfig))
    
    # pass the necessary information to the function to create the plot, including the save file path
    plot_wndsp(title, color_label, lons, lats, u.values, v.values, ws.values, sfig)
# Out:
# Currently plotting: 2020-06-03 00:00
# save filepath: /Users/lgarzio/Documents/rucool/bpu/wrf/tutorials/windspeed10_WRF_3km_20200603_H00.png
# Currently plotting: 2020-06-03 01:00
# save filepath: /Users/lgarzio/Documents/rucool/bpu/wrf/tutorials/windspeed10_WRF_3km_20200603_H01.png
# Currently plotting: 2020-06-03 02:00
# save filepath: /Users/lgarzio/Documents/rucool/bpu/wrf/tutorials/windspeed10_WRF_3km_20200603_H02.png
# Currently plotting: 2020-06-03 03:00
# save filepath: /Users/lgarzio/Documents/rucool/bpu/wrf/tutorials/windspeed10_WRF_3km_20200603_H03.png
# Currently plotting: 2020-06-03 04:00
# save filepath: /Users/lgarzio/Documents/rucool/bpu/wrf/tutorials/windspeed10_WRF_3km_20200603_H04.png
